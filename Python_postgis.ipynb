# %%
from sqlalchemy import create_engine
import geopandas as gpd
import os
os.chdir("C:/Users/joel.rodriguez/ICPR")

# %%
shape = gpd.read_file('pcm_manual_basins.shp')
shape
# Out:
#       Name    Node         ShapeX        ShapeY  \
# 0    31346   31346  490708.750131  1.110216e+06
# 1    31520   31520  494772.077637  1.107785e+06
# 2    37610   37610  490251.250226  1.111407e+06
# 3    37615   37615  490815.625410  1.111644e+06
# 4    31532   31532  494090.062924  1.108809e+06
# 5    31533   31533  494646.250133  1.109139e+06
# 6    31524   31524  495505.139163  1.108890e+06
# 7    31525   31525  495224.375289  1.109748e+06
# 8    31526   31526  495831.250388  1.109808e+06
# 9    31527   31527  495645.000104  1.110357e+06
# 10   31528   31528  495169.972347  1.110289e+06
# 11   31521   31521  495352.415387  1.108480e+06
# 12   31522   31522  494784.049726  1.108446e+06
# 13   31548   31548  492925.000293  1.109701e+06
# 14   31542   31542  492172.304456  1.108575e+06
# 15   31541   31541  490873.877918  1.107750e+06
# 16   31543   31543  490502.014324  1.108524e+06
# 17   31544   31544  490711.250126  1.108878e+06
# ...

# %%
try:
    engine = create_engine('postgresql://postgres:3715@localhost/kh_gis')
    print("Connection set!!!")
except:
    print("Oops!! Something Went wrong!~")
# Out:
# Connection set!!!

# %%
try:
    gdf = gpd.read_file('ALL_DATA.shp')
    gdf.to_postgis(name="all_data", con=engine,if_exists='replace', index=False)
    print("Data has been loaded!!!!!!!!!!!!!")
except:
    print("Oops!! Something Went wrong!~")
# Out:
# Data has been loaded!!!!!!!!!!!!!

# %%
fig, ax = plt.subplots(1, figsize=(10,6))
shape.plot(#column='Node',
           cmap='Blues',
           linewidth=1,
           ax=ax,
           edgecolor='0.5',
           legend = True)
ax.axis('off')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt #if using matplotlib
import plotly.express as px #if using plotly
import geopandas as gpd
fig = px.choropleth(shape, geojson=shape.geometry, 
                    locations=shape.index, color="Name",
                    height=500,
                   color_continuous_scale="red")
fig.update_geos(fitbounds="locations", visible=True)
fig.update_layout(
    title_text='Map'
)

fig.update(layout = dict(title=dict(x=0.5)))
fig.update_layout(
    margin={"r":0,"t":30,"l":10,"b":10},
    coloraxis_colorbar={
        'title':'Sum'})
fig.show()
# Out:
# <div>                            <div id="0bd54404-1eac-4da1-8f2d-d01641d10284" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bd54404-1eac-4da1-8f2d-d01641d10284")) {                    Plotly.newPlot(                        "0bd54404-1eac-4da1-8f2d-d01641d10284",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"geo":"geo","geojson":{"bbox":[490251.250226,1107276.250476,495831.250388,1111643.910542],"features":[{"bbox":[490708.750131,1110216.250667,490708.750131,1110216.250667],"geometry":{"coordinates":[490708.750131,1110216.250667,0.0],"type":"Point"},"id":"0","properties":{},"type":"Feature"},{"bbox":[494772.077637,1107785.162352,494772.077637,1107785.162352],"geometry":{"coordinates":[494772.077637,1107785.162352,0.0],
# ...
